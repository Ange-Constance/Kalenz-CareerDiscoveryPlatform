# %% [markdown]
# # KarrerLenz ML Model Training
#
# This notebook documents the ML pipeline for career classification.
#
# **Model:** TF-IDF (20 features) + Logistic Regression (multinomial)
# **Careers:** UX Research, Health Data, Policy, Backend, DevOps
#
# Run `python run_training.py` from the ml-service directory to train and serialize models.

# %%
import sys
sys.path.insert(0, '..')

from run_training import main
main()
